# %%
print("Hello world")
# Out:
# Hello world

# %%
import nibabel as nib
import os
import matplotlib.pyplot as plt

# %%
fileGet = lambda x: "~/Documents/pancreatic-cancer/" + x
iimage = nib.load(fileGet("100002_00001.nii.gz")).get_fdata().astype('float32')

plt.imshow(iimage[:, :, 0])# mask = nib.load(mask_path).get_fdata().astype('float32'),
